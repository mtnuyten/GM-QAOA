# %% [markdown]
# # QAOA with Grover Mixers (GM-QAOA)

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import SparsePauliOp
from qiskit.primitives import StatevectorEstimator
from qiskit.circuit.library import MCPhaseGate
from scipy.optimize import minimize
from typing import Dict, List, Tuple

# %%
import matplotlib.pyplot as plt
import networkx as nx
G = nx.Graph()
edge_list = [
    (0, 1),
    (0, 2),
    (0, 4),
    (1, 2),
    (2, 3),
    (3, 4),
]
G.add_edges_from(edge_list)
print(f"The graph G has {G.number_of_nodes()} nodes, and {G.number_of_edges()} edges.")
print(f"Edges of the graph:{G.edges()}")
print(f"Nodes adjacent to [1]: {list(G.adj[1])}")
# Out:
# The graph G has 5 nodes, and 6 edges.
# Edges of the graph:[(0, 1), (0, 2), (0, 4), (1, 2), (2, 3), (4, 3)]
# Nodes adjacent to [1]: [0, 2]

# %%
# This is our Cost Hamiltonian
def maxcut_hamiltonian(edges, n_qubits):
    pauli_list = []
    for i, j in edges:
        p_string = ["I"] * n_qubits
        p_string[n_qubits - 1 - i] = "Z" # Qiskit qubit ordering is reversed (q0 is rightmost)
        p_string[n_qubits - 1 - j] = "Z"
        pauli_list.append("".join(p_string))
    
    return SparsePauliOp(pauli_list, coeffs=[1.0] * len(pauli_list))

# %%
edges = G.edges()
n_qubits = G.number_of_nodes()
cost_h = maxcut_hamiltonian(edges, n_qubits)

# %%
def get_cut_size(bitstring, edges):
    """Calculates number of cuts for a specific bitstring (e.g. '101')"""
    cut_value = 0
    # Reverse bitstring because Qiskit is Little-Endian (q0 is rightmost)
    # But for symmetric graphs like this, it doesn't strictly matter.
    # We'll treat index 0 as left-most for simple string indexing.
    for i, j in edges:
        if bitstring[i] != bitstring[j]:
            cut_value += 1
    return cut_value

def get_max_cut(n_qubits, edges):
    """Finds the maximum possible cut size by checking all 2^N states."""
    max_cut = 0
    for i in range(2**n_qubits):
        # Format integer i as binary string
        b_str = format(i, f'0{n_qubits}b') 
        val = get_cut_size(b_str, edges)
        if val > max_cut:
            max_cut = val
    return max_cut

# Calculate the denominator for our ratio
edges = G.edges()
n_qubits = G.number_of_nodes()
cost_h = maxcut_hamiltonian(edges, n_qubits)
MAX_POSSIBLE_CUT = get_max_cut(n_qubits, edges)
print(f"Graph Max Cut (True Maximum): {MAX_POSSIBLE_CUT}")
# Out:
# Graph Max Cut (True Maximum): 5

# %% [markdown]
# ## Grover Mixers
# Definition: $G_M = |z\rangle \langle z|$ is a projector $(G_M^2=G_M)$ onto the space spanned by $|z\rangle$. This Hermitian operator plays the role of the mixing Hamiltonian in the QAOA.

# %%
def grover_phase(qc, beta, z_bits, n_qubits):
    """
    Implements U_M(beta) = I - (1 - e^{-i*beta})|z><z|
    This is a phase rotation on the specific state |z>.
    """
    # 1. change |z> to |11...1> state
    for i, bit in enumerate(reversed(z_bits)):
        if bit == '0':
            qc.x(i)
    # 2. apply multi-controlled phase gate
    gate = MCPhaseGate(-beta, num_ctrl_qubits=n_qubits-1)
    qc.append(gate, range(n_qubits))

    # 3. Flip the qubits back to restore the original basis
    for i, bit in enumerate(reversed(z_bits)):
        if bit == '0':
            qc.x(i)

# H|0> = |+> so U_M(β)=H(I - (1-e^{-iβ))|0><0|)H
def apply_grover_mixer(qc, beta, z_bits, n_qubits):
    qc.h(range(n_qubits))
    grover_phase(qc, beta, z_bits, n_qubits)
    qc.h(range(n_qubits))

# %%
def prepare_feasible_superposition(num_qubits, feasible_bitstrings):
    """
    Creates a statevector that is a uniform superposition of specific bitstrings.
    Example feasible_bitstrings: ['011', '101', '110']
    """
    # 1. Initialize a vector of zeros
    state_dim = 2**num_qubits
    vec = np.zeros(state_dim)
    
    # 2. Set amplitude 1 for feasible states
    # Note: We must convert bitstrings to their integer index
    for bstr in feasible_bitstrings:
        # Qiskit uses little-endian (rightmost bit is q0)
        index = int(bstr, 2)
        vec[index] = 1.0
        
    # 3. Normalize the vector so that the sum of squares = 1
    vec /= np.linalg.norm(vec)
    
    return vec

# %%
# Example: Only bitstrings with exactly two '1's are allowed (Weight-2 subspace)
feasible_list = ['01100', '10100', '11000']
init_vec = prepare_feasible_superposition(5, feasible_list)

# %% [markdown]
# ## Putting the circuit together

# %%
# Define circuit
# The mixer target z is a bitstring "010..." H_M=|z><z| (computational basis)
def gm_qaoa_subspace(p: int, feasible_list: List[Tuple[str,...]], mixer_target_z: str):
    n_qubits = len(mixer_target_z)
    qc = QuantumCircuit(n_qubits)
    
    # --- Initial State (Feasible Subspace) ---
    init_vec = prepare_feasible_superposition(n_qubits, feasible_list)
    qc.prepare_state(init_vec)
    
    gammas = ParameterVector('γ', p)
    betas = ParameterVector('β', p)
    
    for i in range(p):
        # Cost Layer 
        for edge in edges:
            u, v = edge
            # Rzz(angle) is exp(-i * angle/2 * Z Z). 
            # We want exp(-i * gamma * Z Z). So angle = 2 * gamma.
            qc.rzz(2 * gammas[i], u, v)
        
        # Grover Mixer Layer 
        apply_grover_mixer(qc, betas[i], mixer_target_z, n_qubits)
            
    return qc, list(gammas) + list(betas)

# %%
def gm_qaoa_global(p: int, mixer_target_z: str):
    
    n_qubits = len(mixer_target_z)
    qc = QuantumCircuit(n_qubits)
   
    # Initialize |+> state
    qc.h(range(n_qubits))
    
    gammas = ParameterVector('γ', p)
    betas = ParameterVector('β', p)
    
    for i in range(p):
        # Cost Layer 
        for edge in edges:
            u, v = edge
            # Rzz(angle) is exp(-i * angle/2 * Z Z). 
            # We want exp(-i * gamma * Z Z). So angle = 2 * gamma.
            qc.rzz(2 * gammas[i], u, v)
        
        # Grover Mixer Layer 
        apply_grover_mixer(qc, betas[i], mixer_target_z, n_qubits)
            
    return qc, list(gammas) + list(betas)

# %%
import time
# Optimization Loop over Depths ---
p = 10
estimator = StatevectorEstimator()
depths = list(range(1,p+1))
approx_ratios = []
print(f"\n{'Depth':<10} | {'Min Energy':<12} | {'Exp. Cut':<12} | {'Ratio':<10}")
print("-" * 55)

start_time = time.perf_counter()
for p in depths:
    qc, params_list = gm_qaoa_global(p, "00000") 

    def cost_func(params):
        # Tuple: (circuit, observable, parameter_values)
        pub = (qc, cost_h, params)
        result = estimator.run([pub]).result()
        return result[0].data.evs

    # Random initialization
    init_point = []
    for _ in range(p):
        init_point.append(np.random.uniform(0, 2*np.pi)) # Gamma
    for _ in range(p):
        init_point.append(np.random.uniform(0, np.pi))   # Beta
        
    # Optimization
    res = minimize(cost_func, init_point, method='COBYLA', options={'maxiter': 200})
    
    # --- Convert Energy to Cut Value ---
    min_energy = res.fun
    expected_cut = 0.5 * (len(edges) - min_energy)
    
    ratio = expected_cut / MAX_POSSIBLE_CUT
    approx_ratios.append(ratio)
    
    print(f"{p:<10} | {min_energy:<12.4f} | {expected_cut:<12.4f} | {ratio:<10.4f}")

end_time = time.perf_counter()
print(f"runtime: {end_time - start_time}")
# Out:
# Depth      | Min Energy   | Exp. Cut     | Ratio
# -------------------------------------------------------
# 1          | -1.7795      | 3.8898       | 0.7780
# 2          | -2.5630      | 4.2815       | 0.8563
# 3          | -3.1136      | 4.5568       | 0.9114
# 4          | -2.4985      | 4.2492       | 0.8498
# 5          | -3.4903      | 4.7452       | 0.9490
# 6          | -3.5892      | 4.7946       | 0.9589
# 7          | -3.3783      | 4.6891       | 0.9378
# 8          | -3.5975      | 4.7987       | 0.9597
# 9          | -3.9747      | 4.9873       | 0.9975
# 10         | -3.6793      | 4.8396       | 0.9679
# runtime: 26.762003124997136

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(depths, approx_ratios, 'o-', linewidth=2, color='purple')
plt.title('GM-QAOA Performance: Approximation Ratio vs Depth ($p$)')
plt.xlabel('Circuit Depth (p)')
plt.ylabel('Approximation Ratio')
plt.axhline(1.0, color='gray', linestyle='--', label='Perfect Max Cut')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.xticks(depths)
plt.show()

# %%
seed = np.random.seed(42)
G = nx.random_regular_graph(3, 8, seed)

# Visualize the graph
nx.draw(G, with_labels=True)
plt.show()

# %%
# define variables from graph problem
edges = G.edges()
n_qubits = G.number_of_nodes()
cost_h = maxcut_hamiltonian(edges, n_qubits)
# compute the denominator of approximation ratio
MAX_POSSIBLE_CUT = get_max_cut(n_qubits, edges)
print(f"Number of nodes (qubits): {n_qubits}")
print(f"Dimension of Hilbert space: {2**n_qubits}")
print(f"True maximum cut: {MAX_POSSIBLE_CUT}")
# Out:
# Number of nodes (qubits): 8
# Dimension of Hilbert space: 256
# True maximum cut: 10

# %%
import time
# Optimization Loop over Depths ---
p = 10
estimator = StatevectorEstimator()
depths = list(range(1,p+1))
approx_ratios = []
print(f"\n{'Depth':<10} | {'Min Energy':<12} | {'Exp. Cut':<12} | {'Ratio':<10}")
print("-" * 55)

start_time = time.perf_counter()
for p in depths:
    qc, params_list = gm_qaoa_global(p, str(n_qubits*'0')) 

    def cost_func(params):
        # Tuple: (circuit, observable, parameter_values)
        pub = (qc, cost_h, params)
        result = estimator.run([pub]).result()
        return result[0].data.evs

    # Random initialization
    init_point = []
    for _ in range(p):
        init_point.append(np.random.uniform(0, 2*np.pi)) # Gamma
    for _ in range(p):
        init_point.append(np.random.uniform(0, np.pi))   # Beta
        
    # Optimization
    res = minimize(cost_func, init_point, method='COBYLA', options={'maxiter': 200})
    
    # --- Convert Energy to Cut Value ---
    min_energy = res.fun
    expected_cut = 0.5 * (len(edges) - min_energy)
    
    ratio = expected_cut / MAX_POSSIBLE_CUT
    approx_ratios.append(ratio)
    
    print(f"{p:<10} | {min_energy:<12.4f} | {expected_cut:<12.4f} | {ratio:<10.4f}")

end_time = time.perf_counter()
print(f"runtime: {end_time - start_time}")
# Out:
# Depth      | Min Energy   | Exp. Cut     | Ratio
# -------------------------------------------------------
# 1          | -2.6842      | 7.3421       | 0.7342
# 2          | -0.3671      | 6.1836       | 0.6184
# 3          | -3.1074      | 7.5537       | 0.7554
# 4          | -4.2888      | 8.1444       | 0.8144
# 5          | -0.3302      | 6.1651       | 0.6165
# 6          | -5.2798      | 8.6399       | 0.8640
# 7          | -5.1590      | 8.5795       | 0.8580
# 8          | -5.2226      | 8.6113       | 0.8611
# 9          | -4.3172      | 8.1586       | 0.8159
# 10         | -5.2508      | 8.6254       | 0.8625
# runtime: 109.61618983300286

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(depths, approx_ratios, 'o-', linewidth=2, color='purple')
plt.title('GM-QAOA Performance: Approximation Ratio vs Depth ($p$)')
plt.xlabel('Circuit Depth (p)')
plt.ylabel('Approximation Ratio')
plt.axhline(1.0, color='gray', linestyle='--', label='Perfect Max Cut')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.xticks(depths)
plt.show()

# %%
seed = np.random.seed(42)
G = nx.random_regular_graph(3, 6, seed)

# Visualize the graph
nx.draw(G, with_labels=True)
plt.show()

# %%
# define variables from graph problem
edges = G.edges()
n_qubits = G.number_of_nodes()
cost_h = maxcut_hamiltonian(edges, n_qubits)
# compute the denominator of approximation ratio
MAX_POSSIBLE_CUT = get_max_cut(n_qubits, edges)
print(f"Number of nodes (qubits): {n_qubits}")
print(f"Dimension of Hilbert space: {2**n_qubits}")
print(f"True maximum cut: {MAX_POSSIBLE_CUT}")
# Out:
# Number of nodes (qubits): 6
# Dimension of Hilbert space: 64
# True maximum cut: 7

# %%
import time
# Optimization Loop over Depths ---
p = 10
estimator = StatevectorEstimator()
depths = list(range(1,p+1))
approx_ratios = []
print(f"\n{'Depth':<10} | {'Min Energy':<12} | {'Exp. Cut':<12} | {'Ratio':<10}")
print("-" * 55)

start_time = time.perf_counter()
for p in depths:
    qc, params_list = gm_qaoa_global(p, str(n_qubits*'0')) 

    def cost_func(params):
        # Tuple: (circuit, observable, parameter_values)
        pub = (qc, cost_h, params)
        result = estimator.run([pub]).result()
        return result[0].data.evs

    # Random initialization
    init_point = []
    for _ in range(p):
        init_point.append(np.random.uniform(0, 2*np.pi)) # Gamma
    for _ in range(p):
        init_point.append(np.random.uniform(0, np.pi))   # Beta
        
    # Optimization
    res = minimize(cost_func, init_point, method='COBYLA', options={'maxiter': 200})
    
    # --- Convert Energy to Cut Value ---
    min_energy = res.fun
    expected_cut = 0.5 * (len(edges) - min_energy)
    
    ratio = expected_cut / MAX_POSSIBLE_CUT
    approx_ratios.append(ratio)
    
    print(f"{p:<10} | {min_energy:<12.4f} | {expected_cut:<12.4f} | {ratio:<10.4f}")

end_time = time.perf_counter()
print(f"runtime: {end_time - start_time}")
# Out:
# Depth      | Min Energy   | Exp. Cut     | Ratio
# -------------------------------------------------------
# 1          | -2.1766      | 5.5883       | 0.7983
# 2          | -2.5112      | 5.7556       | 0.8222
# 3          | -2.5117      | 5.7558       | 0.8223
# 4          | -2.3646      | 5.6823       | 0.8118
# 5          | -3.4012      | 6.2006       | 0.8858
# 6          | -2.6339      | 5.8170       | 0.8310
# 7          | -3.6956      | 6.3478       | 0.9068
# 8          | -4.0843      | 6.5422       | 0.9346
# 9          | -3.4605      | 6.2303       | 0.8900
# 10         | -4.7033      | 6.8516       | 0.9788
# runtime: 44.53370775000076

# %%
plt.figure(figsize=(8, 5))
plt.plot(depths, approx_ratios, 'o-', linewidth=2, color='purple')
plt.title('GM-QAOA Performance: Approximation Ratio vs Depth ($p$)')
plt.xlabel('Circuit Depth (p)')
plt.ylabel('Approximation Ratio')
plt.axhline(1.0, color='gray', linestyle='--', label='Perfect Max Cut')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.xticks(depths)
plt.show()

# %%
seed = np.random.seed(42)
G = nx.random_regular_graph(3, 10, seed)

# Visualize the graph
nx.draw(G, with_labels=True)
plt.show()

# %%
# define variables from graph problem
edges = G.edges()
n_qubits = G.number_of_nodes()
cost_h = maxcut_hamiltonian(edges, n_qubits)
# compute the denominator of approximation ratio
MAX_POSSIBLE_CUT = get_max_cut(n_qubits, edges)
print(f"Number of nodes (qubits): {n_qubits}")
print(f"Dimension of Hilbert space: {2**n_qubits}")
print(f"True maximum cut: {MAX_POSSIBLE_CUT}")
# Out:
# Number of nodes (qubits): 10
# Dimension of Hilbert space: 1024
# True maximum cut: 13

# %%
import time
# Optimization Loop over Depths ---
p = 10
estimator = StatevectorEstimator()
depths = list(range(1,p+1))
approx_ratios = []
print(f"\n{'Depth':<10} | {'Min Energy':<12} | {'Exp. Cut':<12} | {'Ratio':<10}")
print("-" * 55)

start_time = time.perf_counter()
for p in depths:
    qc, params_list = gm_qaoa_global(p, str(n_qubits*'0')) 

    def cost_func(params):
        # Tuple: (circuit, observable, parameter_values)
        pub = (qc, cost_h, params)
        result = estimator.run([pub]).result()
        return result[0].data.evs

    # Random initialization
    init_point = []
    for _ in range(p):
        init_point.append(np.random.uniform(0, 2*np.pi)) # Gamma
    for _ in range(p):
        init_point.append(np.random.uniform(0, np.pi))   # Beta
        
    # Optimization
    res = minimize(cost_func, init_point, method='COBYLA', options={'maxiter': 200})
    
    # --- Convert Energy to Cut Value ---
    min_energy = res.fun
    expected_cut = 0.5 * (len(edges) - min_energy)
    
    ratio = expected_cut / MAX_POSSIBLE_CUT
    approx_ratios.append(ratio)
    
    print(f"{p:<10} | {min_energy:<12.4f} | {expected_cut:<12.4f} | {ratio:<10.4f}")

end_time = time.perf_counter()
print(f"runtime: {end_time - start_time}")
# Out:
# Depth      | Min Energy   | Exp. Cut     | Ratio
# -------------------------------------------------------
# 1          | -3.2185      | 9.1093       | 0.7007
# 2          | -3.2175      | 9.1087       | 0.7007
# 3          | -3.2156      | 9.1078       | 0.7006
# 4          | -3.0823      | 9.0412       | 0.6955
# 5          | -3.5549      | 9.2775       | 0.7137
# 6          | -4.2804      | 9.6402       | 0.7416
# 7          | -5.2609      | 10.1304      | 0.7793
# 8          | -5.7200      | 10.3600      | 0.7969
# 9          | -3.2017      | 9.1009       | 0.7001
# 10         | -3.9020      | 9.4510       | 0.7270
# runtime: 248.62848070800828

# %%
plt.figure(figsize=(8, 5))
plt.plot(depths, approx_ratios, 'o-', linewidth=2, color='purple')
plt.title('GM-QAOA Performance: Approximation Ratio vs Depth ($p$)')
plt.xlabel('Circuit Depth (p)')
plt.ylabel('Approximation Ratio')
plt.axhline(1.0, color='gray', linestyle='--', label='Perfect Max Cut')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.xticks(depths)
plt.show()
